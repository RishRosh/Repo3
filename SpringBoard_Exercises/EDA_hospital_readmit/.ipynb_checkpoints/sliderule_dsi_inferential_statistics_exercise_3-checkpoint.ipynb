# %% [markdown]
# # Hospital Readmissions Data Analysis and Recommendations for Reduction
#
# ### Background
# In October 2012, the US government's Center for Medicare and Medicaid Services (CMS) began reducing Medicare payments for Inpatient Prospective Payment System hospitals with excess readmissions. Excess readmissions are measured by a ratio, by dividing a hospital’s number of “predicted” 30-day readmissions for heart attack, heart failure, and pneumonia by the number that would be “expected,” based on an average hospital with similar patients. A ratio greater than 1 indicates excess readmissions.
#
# ### Exercise Directions
#
# In this exercise, you will:
# + critique a preliminary analysis of readmissions data and recommendations (provided below) for reducing the readmissions rate
# + construct a statistically sound analysis and make recommendations of your own
#
# More instructions provided below. Include your work **in this notebook and submit to your Github account**.
#
# ### Resources
# + Data source: https://data.medicare.gov/Hospital-Compare/Hospital-Readmission-Reduction/9n3s-kdb3
# + More information: http://www.cms.gov/Medicare/medicare-fee-for-service-payment/acuteinpatientPPS/readmissions-reduction-program.html
# + Markdown syntax: http://nestacms.com/docs/creating-content/markdown-cheat-sheet
# ****

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import bokeh.plotting as bkp
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# read in readmissions data provided
hospital_read_df = pd.read_csv('data/cms_hospital_readmissions.csv')

# %% [markdown]
# ****
# ## Preliminary Analysis

# %%
# deal with missing and inconvenient portions of data 
clean_hospital_read_df = hospital_read_df[hospital_read_df['Number of Discharges'] != 'Not Available']
clean_hospital_read_df.loc[:, 'Number of Discharges'] = clean_hospital_read_df['Number of Discharges'].astype(int)
clean_hospital_read_df = clean_hospital_read_df.sort_values('Number of Discharges')
# Out:
# C:\Users\Rishi\Anaconda3\lib\site-packages\pandas\core\indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# generate a scatterplot for number of discharges vs. excess rate of readmissions
# lists work better with matplotlib scatterplot function
x = [a for a in clean_hospital_read_df['Number of Discharges'][81:-3]]
y = list(clean_hospital_read_df['Excess Readmission Ratio'][81:-3])

fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(x, y,alpha=0.2)

ax.fill_between([0,350], 1.15, 2, facecolor='red', alpha = .15, interpolate=True)
ax.fill_between([800,2500], .5, .95, facecolor='green', alpha = .15, interpolate=True)

ax.set_xlim([0, max(x)])
ax.set_xlabel('Number of discharges', fontsize=12)
ax.set_ylabel('Excess rate of readmissions', fontsize=12)
ax.set_title('Scatterplot of number of discharges vs. excess rate of readmissions', fontsize=14)

ax.grid(True)
fig.tight_layout()

# %% [markdown]
# ****
#
# ## Preliminary Report
#
# Read the following results/report. While you are reading it, think about if the conclusions are correct, incorrect, misleading or unfounded. Think about what you would change or what additional analyses you would perform.
#
# **A. Initial observations based on the plot above**
# + Overall, rate of readmissions is trending down with increasing number of discharges (RP:May not be true)
# + With lower number of discharges, there is a greater incidence of excess rate of readmissions (area shaded red)
# + With higher number of discharges, there is a greater incidence of lower rates of readmissions (area shaded green)
#
# **B. Statistics**
# + In hospitals/facilities with number of discharges < 100, mean excess readmission rate is 1.023 and 63% have excess readmission rate greater than 1 (RP: Validate)
# + In hospitals/facilities with number of discharges > 1000, mean excess readmission rate is 0.978 and 44% have excess readmission rate greater than 1
#
# **C. Conclusions**
# + There is a significant correlation between hospital capacity (number of discharges) and readmission rates.
# + Smaller hospitals/facilities may be lacking necessary resources to ensure quality care and prevent complications that lead to readmissions.
#
# **D. Regulatory policy recommendations**
# + Hospitals/facilties with small capacity (< 300) should be required to demonstrate upgraded resource allocation for quality care to continue operation.
# + Directives and incentives should be provided for consolidation of hospitals and facilities to have a smaller number of them with higher capacity and number of discharges.

# %% [markdown]
# ****
# ### Exercise
#
# Include your work on the following **in this notebook and submit to your Github account**.
#
# A. Do you agree with the above analysis and recommendations? Why or why not?
#
# B. Provide support for your arguments and your own recommendations with a statistically sound analysis:
#
#    1. Setup an appropriate hypothesis test.
#    2. Compute and report the observed significance value (or p-value).
#    3. Report statistical significance for $\alpha$ = .01.
#    4. Discuss statistical significance and practical significance. Do they differ here? How does this change your recommendation to the client?
#    5. Look at the scatterplot above.
#       - What are the advantages and disadvantages of using this plot to convey information?
#       - Construct another plot that conveys the same information in a more direct manner.
#
#
#
# You can compose in notebook cells using Markdown:
# + In the control panel at the top, choose Cell > Cell Type > Markdown
# + Markdown syntax: http://nestacms.com/docs/creating-content/markdown-cheat-sheet
# ****

# %%
# Your turn
# clean_hospital_read_df[
# a = np.array(np.isnan(clean_hospital_read_df[clean_hospital_read_df['Footnote'] > 0]['Footnote']) )
b = clean_hospital_read_df[clean_hospital_read_df['Footnote'] > 0]['Excess Readmission Ratio']
# clean_hospital_read_df[pd.DataFrame(np.isnan(b))]
# clean_hospital_read_df[~np.isnan(b)]
clean_hospital_read_df[81:]
# Out:
#                                            Hospital Name  Provider Number  \
# 1832   UNIVERSITY OF MD CHARLES REGIONAL  MEDICAL CENTER           210035
# 1699                           ATLANTIC GENERAL HOSPITAL           210061
# 1774                            MERCY MEDICAL CENTER INC           210008
# 1853              KAISER FOUNDATION HOSPITAL-SANTA CLARA            50071
# 1290                                  PALMERTON HOSPITAL           390019
# 1602      TENNOVA HEALTHCARE-JEFFERSON MEMORIAL HOSPITAL           440056
# 2048                     FORT MADISON COMMUNITY HOSPITAL           160122
# 2441                                     ISLAND HOSPITAL           500007
# 2512                        NORTH CENTRAL BRONX HOSPITAL           330385
# 2825                  KAISER FOUNDATION HOSPITAL FONTANA            50140
# 3828           SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD            50135
# 5125                        WESTCHESTER GENERAL HOSPITAL           100284
# 3312                            ALBANY MEMORIAL HOSPITAL           330003
# 2378                         GREENVIEW REGIONAL HOSPITAL           180124
# 2670                          MISSION COMMUNITY HOSPITAL            50704
# 2944                 SETON MEDICAL CENTER HARKER HEIGHTS           670080
# 1238                     MURRAY-CALLOWAY COUNTY HOSPITAL           180027
# 1395                        NORTH CENTRAL BRONX HOSPITAL           330385
# 3145                       BROWARD HEALTH IMPERIAL POINT           100200
# 3207                               ALLEN PARISH HOSPITAL           190133
# 1471                    PORTERVILLE DEVELOPMENTAL CENTER            50546
# 1838                            HARMON MEMORIAL HOSPITAL           370036
# 4092                          LAC/HARBOR-UCLA MED CENTER            50376
# 2252   CAREPOINT HEALTH-HOBOKEN UNIVERSITY MEDICAL CE...           310040
# 3087                       FORT DEFIANCE INDIAN HOSPITAL            30071
# 4317                               MINERS MEDICAL CENTER           390130
# 5309                    COMMUNITY HOSPITAL OF LONG BEACH            50727
# 2952                                   ST MARYS HOSPITAL           140026
# 3406                                DOCTORS HOSPITAL INC           100296
# 738                    SAINT CATHERINE REGIONAL HOSPITAL           150163
# ...                                                  ...              ...
# 7147                           MORRISTOWN MEDICAL CENTER           310015
# 897                                      VALLEY HOSPITAL           310012
# 13326                             SWEDISH MEDICAL CENTER           500027
# 7872                ST FRANCIS HOSPITAL & MEDICAL CENTER            70002
# 9444                                   EVANSTON HOSPITAL           140010
# 13723              PROVIDENCE SAINT JOHN'S HEALTH CENTER            50290
# 1605                            COMMUNITY MEDICAL CENTER           310041
# 12910                          BAPTIST HEALTH LOUISVILLE           180130
# 2758                               LEE MEMORIAL HOSPITAL           100012
# 7934                 CAROLINAS MEDICAL  CENTER-PINEVILLE           340098
# 1352                      SOUTHCOAST HOSPITAL GROUP, INC           220074
# 3042                        BEAUMONT HOSPITAL, ROYAL OAK           230130
# 1448                 NEW HANOVER REGIONAL MEDICAL CENTER           340141
# 2846               CHRISTIANA CARE HEALTH SERVICES, INC.            80001
# 8249                                  METHODIST HOSPITAL           450388
# 3202              METHODIST HEALTHCARE MEMPHIS HOSPITALS           440049
# 13730                          HOAG ORTHOPEDIC INSTITUTE            50769
# 2440                                    FLORIDA HOSPITAL           100007
# 11545         MCBRIDE CLINIC ORTHOPEDIC HOSPITAL,  L L C           370222
# 1805                      NEW YORK-PRESBYTERIAN HOSPITAL           330101
# 8818               CHRISTIANA CARE HEALTH SERVICES, INC.            80001
# 572                       SOUTHCOAST HOSPITAL GROUP, INC           220074
# 136                         BEAUMONT HOSPITAL, ROYAL OAK           230130
# 1698                                    FLORIDA HOSPITAL           100007
# 1242                                    FLORIDA HOSPITAL           100007
# 8126                           NAPLES COMMUNITY HOSPITAL           100018
# 6643                            COMMUNITY MEDICAL CENTER           310041
# 1892                                    FLORIDA HOSPITAL           100007
# 13615                       NEW ENGLAND BAPTIST HOSPITAL           220088
# 13666                       HOSPITAL FOR SPECIAL SURGERY           330270
#
#       State            Measure Name  Number of Discharges  Footnote  \
# 1832     MD       READM-30-AMI-HRRP                    25       NaN
# 1699     MD       READM-30-AMI-HRRP                    27       NaN
# 1774     MD       READM-30-AMI-HRRP                    28       NaN
# 1853     CA        READM-30-HF-HRRP                    29       NaN
# 1290     PA       READM-30-AMI-HRRP                    30       NaN
# 1602     TN       READM-30-AMI-HRRP                    31       NaN
# 2048     IA       READM-30-AMI-HRRP                    33       NaN
# 2441     WA       READM-30-AMI-HRRP                    34       NaN
# 2512     NY        READM-30-HF-HRRP                    34       NaN
# 2825     CA        READM-30-PN-HRRP                    34       NaN
# 3828     CA       READM-30-AMI-HRRP                    35       NaN
# 5125     FL       READM-30-AMI-HRRP                    35       NaN
# 3312     NY       READM-30-AMI-HRRP                    35       NaN
# 2378     KY       READM-30-AMI-HRRP                    35       NaN
# 2670     CA       READM-30-AMI-HRRP                    35       NaN
# 2944     TX        READM-30-PN-HRRP                    35       NaN
# 1238     KY       READM-30-AMI-HRRP                    36       NaN
# 1395     NY        READM-30-PN-HRRP                    36       NaN
# 3145     FL       READM-30-AMI-HRRP                    37       NaN
# 3207     LA        READM-30-HF-HRRP                    37       NaN
# 1471     CA        READM-30-PN-HRRP                    37       NaN
# 1838     OK        READM-30-PN-HRRP                    37       NaN
# 4092     CA      READM-30-COPD-HRRP                    37       NaN
# 2252     NJ       READM-30-AMI-HRRP                    37       NaN
# 3087     AZ        READM-30-HF-HRRP                    37       NaN
# 4317     PA        READM-30-HF-HRRP                    38       NaN
# 5309     CA       READM-30-AMI-HRRP                    38       NaN
# 2952     IL       READM-30-AMI-HRRP                    38       NaN
# 3406     FL       READM-30-AMI-HRRP                    38       NaN
# 738      IN        READM-30-HF-HRRP                    39       NaN
# ...     ...                     ...                   ...       ...
# 7147     NJ  READM-30-HIP-KNEE-HRRP                  2042       NaN
# 897      NJ        READM-30-HF-HRRP                  2060       NaN
# 13326    WA  READM-30-HIP-KNEE-HRRP                  2089       NaN
# 7872     CT  READM-30-HIP-KNEE-HRRP                  2106       NaN
# 9444     IL        READM-30-HF-HRRP                  2112       NaN
# 13723    CA  READM-30-HIP-KNEE-HRRP                  2189       NaN
# 1605     NJ        READM-30-HF-HRRP                  2190       NaN
# 12910    KY  READM-30-HIP-KNEE-HRRP                  2196       NaN
# 2758     FL  READM-30-HIP-KNEE-HRRP                  2198       NaN
# 7934     NC  READM-30-HIP-KNEE-HRRP                  2209       NaN
# 1352     MA        READM-30-HF-HRRP                  2278       NaN
# 3042     MI        READM-30-HF-HRRP                  2314       NaN
# 1448     NC  READM-30-HIP-KNEE-HRRP                  2318       NaN
# 2846     DE  READM-30-HIP-KNEE-HRRP                  2341       NaN
# 8249     TX        READM-30-HF-HRRP                  2353       NaN
# 3202     TN        READM-30-HF-HRRP                  2388       NaN
# 13730    CA  READM-30-HIP-KNEE-HRRP                  2393       NaN
# 2440     FL        READM-30-PN-HRRP                  2430       NaN
# 11545    OK  READM-30-HIP-KNEE-HRRP                  2469       NaN
# 1805     NY        READM-30-HF-HRRP                  2476       NaN
# 8818     DE        READM-30-HF-HRRP                  2509       NaN
# 572      MA      READM-30-COPD-HRRP                  2565       NaN
# 136      MI  READM-30-HIP-KNEE-HRRP                  2581       NaN
# 1698     FL  READM-30-HIP-KNEE-HRRP                  2596       NaN
# 1242     FL      READM-30-COPD-HRRP                  2705       NaN
# 8126     FL  READM-30-HIP-KNEE-HRRP                  2716       NaN
# 6643     NJ      READM-30-COPD-HRRP                  2740       NaN
# 1892     FL        READM-30-HF-HRRP                  3570       NaN
# 13615    MA  READM-30-HIP-KNEE-HRRP                  3980       NaN
# 13666    NY  READM-30-HIP-KNEE-HRRP                  6793       NaN
#
#        Excess Readmission Ratio  Predicted Readmission Rate  \
# 1832                     1.0914                        26.8
# 1699                     1.0961                        24.8
# 1774                     1.0934                        24.4
# 1853                     1.0908                        21.0
# 1290                     1.1123                        23.2
# 1602                     1.0992                        24.2
# 2048                     1.0847                        22.6
# 2441                     1.0738                        20.8
# 2512                     1.0720                        23.3
# 2825                     1.0651                        20.7
# 3828                     1.0444                        26.7
# 5125                     1.0228                        27.5
# 3312                     1.0548                        22.7
# 2378                     1.0756                        20.1
# 2670                     1.0683                        25.9
# 2944                     1.0622                        20.7
# 2758                         5.2                   122.0  07/01/2010
# 7934                         4.5                    97.0  07/01/2010
# 1352                        22.5                   574.0  07/01/2010
# 3042                        24.1                   596.0  07/01/2010
# 1448                         5.0                   129.0  07/01/2010
# 2846                         5.1                   129.0  07/01/2010
# 8249                        22.5                   516.0  07/01/2010
# 3202                        22.2                   564.0  07/01/2010
# 13730                        4.9                    54.0  07/01/2010
# 2440                        17.3                   456.0  07/01/2010
# 11545                        4.9                   110.0  07/01/2010
# 1805                        22.7                   619.0  07/01/2010
# 8818                        22.5                   546.0  07/01/2010
# 572                         20.4                   619.0  07/01/2010
# 136                          5.9                   197.0  07/01/2010
# 1698                         5.1                   147.0  07/01/2010
# 1242                        19.7                   603.0  07/01/2010
# 8126                         5.3                   141.0  07/01/2010
# 6643                        22.7                   623.0  07/01/2010
# 1892                        22.5                   879.0  07/01/2010
# 13615                        4.8                   142.0  07/01/2010
# 13666                        5.3                   258.0  07/01/2010
#
#          End Date
# 1832   06/30/2013
# 1699   06/30/2013
# 1774   06/30/2013
# 1853   06/30/2013
# 1290   06/30/2013
# 1602   06/30/2013
# 2048   06/30/2013
# 2441   06/30/2013
# 2512   06/30/2013
# 2825   06/30/2013
# 3828   06/30/2013
# 5125   06/30/2013
# 3312   06/30/2013
# 2378   06/30/2013
# 2670   06/30/2013
# 2944   06/30/2013
# 1238   06/30/2013
# 1395   06/30/2013
# 3145   06/30/2013
# 3207   06/30/2013
# 1471   06/30/2013
# 1838   06/30/2013
# 4092   06/30/2013
# 2252   06/30/2013
# 3087   06/30/2013
# 4317   06/30/2013
# 5309   06/30/2013
# 2952   06/30/2013
# 3406   06/30/2013
# 738    06/30/2013
# ...           ...
# 7147   06/30/2013
# 897    06/30/2013
# 13326  06/30/2013
# 7872   06/30/2013
# 9444   06/30/2013
# 13723  06/30/2013
# 1605   06/30/2013
# 12910  06/30/2013
# 2758   06/30/2013
# 7934   06/30/2013
# 1352   06/30/2013
# 3042   06/30/2013
# 1448   06/30/2013
# 2846   06/30/2013
# 8249   06/30/2013
# 3202   06/30/2013
# 13730  06/30/2013
# 2440   06/30/2013
# 11545  06/30/2013
# 1805   06/30/2013
# 8818   06/30/2013
# 572    06/30/2013
# 136    06/30/2013
# 1698   06/30/2013
# 1242   06/30/2013
# 8126   06/30/2013
# 6643   06/30/2013
# 1892   06/30/2013
# 13615  06/30/2013
# 13666  06/30/2013
#
# [11497 rows x 12 columns]

# %%
clean_limited_h_r_df = clean_hospital_read_df[81:-3]

# %%
def ecdf(data):
    data_s = np.sort(data)
    x = data_s
    y = np.arange(1, len(x) + 1)/len(x) 
    return(x,y)

# %%
NoD_x, NoD_y = ecdf(clean_limited_h_r_df['Number of Discharges'])
_ = plt.plot(NoD_x,NoD_y,marker='.',linestyle='none')

# %%
clean_limited_h_r_df[clean_limited_h_r_df['Measure Name'] == 'READM-30-HIP-KNEE-HRRP']
# Out:
#                                            Hospital Name  Provider Number  \
# 29                              RALEIGH GENERAL HOSPITAL           510070
# 31                  SOUTHWEST MS REGIONAL MEDICAL CENTER           250097
# 1448                 NEW HANOVER REGIONAL MEDICAL CENTER           340141
# 2846               CHRISTIANA CARE HEALTH SERVICES, INC.            80001
# 13730                          HOAG ORTHOPEDIC INSTITUTE            50769
# 11545         MCBRIDE CLINIC ORTHOPEDIC HOSPITAL,  L L C           370222
# 136                         BEAUMONT HOSPITAL, ROYAL OAK           230130
# 1698                                    FLORIDA HOSPITAL           100007
# 8126                           NAPLES COMMUNITY HOSPITAL           100018
#
#       State            Measure Name  Number of Discharges  Footnote  \
# 29       CA  READM-30-HIP-KNEE-HRRP                    57       NaN
# 31       CA  READM-30-HIP-KNEE-HRRP                    76       NaN
# 67       CA  READM-30-HIP-KNEE-HRRP                    77       NaN
# 145      CA  READM-30-HIP-KNEE-HRRP                    82       NaN
# 41       CA  READM-30-HIP-KNEE-HRRP                    87       NaN
# 124      CA  READM-30-HIP-KNEE-HRRP                    90       NaN
# 296      CA  READM-30-HIP-KNEE-HRRP                    92       NaN
# 232      CA  READM-30-HIP-KNEE-HRRP                    95       NaN
# 24       CA  READM-30-HIP-KNEE-HRRP                    97       NaN
# 19       CA  READM-30-HIP-KNEE-HRRP                    98       NaN
# 8        CA  READM-30-HIP-KNEE-HRRP                    98       NaN
# 200      CA  READM-30-HIP-KNEE-HRRP                    99       NaN
# 434      CA  READM-30-HIP-KNEE-HRRP                   100       NaN
# 135      CA  READM-30-HIP-KNEE-HRRP                   106       NaN
# 11       CA  READM-30-HIP-KNEE-HRRP                   108       NaN
# 70       CA  READM-30-HIP-KNEE-HRRP                   111       NaN
# 305      CA  READM-30-HIP-KNEE-HRRP                   114       NaN
# 545      CA  READM-30-HIP-KNEE-HRRP                   115       NaN
# 69       CA  READM-30-HIP-KNEE-HRRP                   115       NaN
# 242      CA  READM-30-HIP-KNEE-HRRP                   116       NaN
# 79       CA  READM-30-HIP-KNEE-HRRP                   116       NaN
# 17       CA  READM-30-HIP-KNEE-HRRP                   117       NaN
# 351      CA  READM-30-HIP-KNEE-HRRP                   118       NaN
# 616      CA  READM-30-HIP-KNEE-HRRP                   118       NaN
# 30       CA  READM-30-HIP-KNEE-HRRP                   118       NaN
# 10       CA  READM-30-HIP-KNEE-HRRP                   121       NaN
# 376      CA  READM-30-HIP-KNEE-HRRP                   121       NaN
# 223      CA  READM-30-HIP-KNEE-HRRP                   121       NaN
# 1157     CA  READM-30-HIP-KNEE-HRRP                   125       NaN
# 206      CA  READM-30-HIP-KNEE-HRRP                   125       NaN
# ...     ...                     ...                   ...       ...
# 1660     CA  READM-30-HIP-KNEE-HRRP                  1766       NaN
# 12828    CA  READM-30-HIP-KNEE-HRRP                  1773       NaN
# 13636    CA  READM-30-HIP-KNEE-HRRP                  1779       NaN
# 13675    CA  READM-30-HIP-KNEE-HRRP                  1815       NaN
# 13708    CA  READM-30-HIP-KNEE-HRRP                  1817       NaN
# 6728     CA  READM-30-HIP-KNEE-HRRP                  1822       NaN
# 13162    CA  READM-30-HIP-KNEE-HRRP                  1845       NaN
# 5852     CA  READM-30-HIP-KNEE-HRRP                  1849       NaN
# 13293    CA  READM-30-HIP-KNEE-HRRP                  1901       NaN
# 13647    CA  READM-30-HIP-KNEE-HRRP                  1918       NaN
# 13602    CA  READM-30-HIP-KNEE-HRRP                  1951       NaN
# 13641    CA  READM-30-HIP-KNEE-HRRP                  1956       NaN
# 13616    CA  READM-30-HIP-KNEE-HRRP                  1957       NaN
# 12526    CA  READM-30-HIP-KNEE-HRRP                  1974       NaN
# 13577    CA  READM-30-HIP-KNEE-HRRP                  1975       NaN
# 10370    CA  READM-30-HIP-KNEE-HRRP                  2011       NaN
# 7147     CA  READM-30-HIP-KNEE-HRRP                  2042       NaN
# 13326    CA  READM-30-HIP-KNEE-HRRP                  2089       NaN
# 7872     CA  READM-30-HIP-KNEE-HRRP                  2106       NaN
# 13723    CA  READM-30-HIP-KNEE-HRRP                  2189       NaN
# 12910    CA  READM-30-HIP-KNEE-HRRP                  2196       NaN
# 2758     CA  READM-30-HIP-KNEE-HRRP                  2198       NaN
# 7934     CA  READM-30-HIP-KNEE-HRRP                  2209       NaN
# 1448     CA  READM-30-HIP-KNEE-HRRP                  2318       NaN
# 2846     CA  READM-30-HIP-KNEE-HRRP                  2341       NaN
# 13730    CA  READM-30-HIP-KNEE-HRRP                  2393       NaN
# 11545    CA  READM-30-HIP-KNEE-HRRP                  2469       NaN
# 136      CA  READM-30-HIP-KNEE-HRRP                  2581       NaN
# 1698     CA  READM-30-HIP-KNEE-HRRP                  2596       NaN
# 8126     CA  READM-30-HIP-KNEE-HRRP                  2716       NaN
#
#        Excess Readmission Ratio  Predicted Readmission Rate  \
# 29                       1.3992                         8.5
# 31                       1.3966                         8.9
# 67                       1.3254                         7.5
# 145                      1.2519                         8.2
# 41                       1.3755                        10.3
# 124                      1.2686                         7.3
# 296                      1.2090                         8.1
# 232                      1.2260                         7.7
# 24                       1.4088                         9.9
# 19                       1.4333                         7.6
# 8                        1.4953                         7.9
# 200                      1.2348                         7.2
# 434                      1.1820                         7.9
# 135                      1.2586                         6.5
# 11                       1.4691                         9.2
# 70                       1.3177                         6.4
# 305                      1.2067                         6.7
# 545                      1.1677                         7.1
# 69                       1.3184                         7.8
# 242                      1.2221                         6.4
# 79                       1.3115                         7.0
# 17                       1.4486                         7.2
# 351                      1.1954                         8.2
# 616                      1.1576                         7.1
# 30                       1.3968                         6.8
# 10                       1.4776                         9.0
# 376                      1.1916                         6.5
# 223                      1.2286                         6.0
# 1157                     1.1191                         8.7
# 206                      1.2331                         8.9
# ...                         ...                         ...
# 1660                     1.0974                         5.5
# 12828                    0.8801                         4.2
# 13636                    0.7564                         3.2
# 13675                    0.7313                         3.8
# 13708                    0.6987                         3.3
# 6728                     0.9991                         4.9
# 13162                    0.8561                         4.4
# 5852                     1.0120                         4.8
# 13293                    0.8416                         4.2
# 13647                    0.7504                         3.5
# 13602                    0.7747                         3.9
# 13641                    0.7549                         4.0
# 13616                    0.7676                         3.6
# 12526                    0.8943                         4.4
# 13577                    0.7812                         3.7
# 10370                    0.9485                         4.4
# 7147                     0.9935                         5.1
# 13326                    0.8384                         3.7
# 7872                     0.9839                         5.0
# 13723                    0.6350                         3.2
# 12910                    0.8747                         4.3
# 2758                     1.0663                         5.5
# 19     06/30/2013
# 8      06/30/2013
# 200    06/30/2013
# 434    06/30/2013
# 135    06/30/2013
# 11     06/30/2013
# 70     06/30/2013
# 305    06/30/2013
# 545    06/30/2013
# 69     06/30/2013
# 242    06/30/2013
# 79     06/30/2013
# 17     06/30/2013
# 351    06/30/2013
# 616    06/30/2013
# 30     06/30/2013
# 10     06/30/2013
# 376    06/30/2013
# 223    06/30/2013
# 1157   06/30/2013
# 206    06/30/2013
# ...           ...
# 1660   06/30/2013
# 12828  06/30/2013
# 13636  06/30/2013
# 13675  06/30/2013
# 13708  06/30/2013
# 6728   06/30/2013
# 13162  06/30/2013
# 5852   06/30/2013
# 13293  06/30/2013
# 13647  06/30/2013
# 13602  06/30/2013
# 13641  06/30/2013
# 13616  06/30/2013
# 12526  06/30/2013
# 13577  06/30/2013
# 10370  06/30/2013
# 7147   06/30/2013
# 13326  06/30/2013
# 7872   06/30/2013
# 13723  06/30/2013
# 12910  06/30/2013
# 2758   06/30/2013
# 7934   06/30/2013
# 1448   06/30/2013
# 2846   06/30/2013
# 13730  06/30/2013
# 11545  06/30/2013
# 136    06/30/2013
# 1698   06/30/2013
# 8126   06/30/2013
#
# [1369 rows x 12 columns]

# %% [markdown]
# #### A. Do you agree with the above analysis and recommendations? Why or why not?
#
# ##### Validate the statements:
# i. With lower number of discharges, there is a greater incidence of excess rate of readmissions (area shaded red)
#
# ii. With higher number of discharges, there is a greater incidence of lower rates of readmissions (area shaded green)
#
# iii. In hospitals/facilities with number of discharges < 100, mean excess readmission rate is 1.023 and 63% have excess readmission rate greater than 1 (RP: Validate)
#
# iv. In hospitals/facilities with number of discharges > 1000, mean excess readmission rate is 0.978 and 44% have excess readmission rate greater than 1
#
# Assume lower = 350 or less, based on red shaded area.

# %%
lower_discharges = clean_limited_h_r_df[clean_limited_h_r_df['Number of Discharges'] <= 350]['Excess Readmission Ratio']

higher_discharges = clean_limited_h_r_df[clean_limited_h_r_df['Number of Discharges'] > 350]['Excess Readmission Ratio']
print('Readmission rate with lower discharges: ', lower_discharges.mean())
print('Readmission rate with higher discharges: ', higher_discharges.mean())
# Out:
# Readmission rate with lower discharges:  1.0132787273505486
# Readmission rate with higher discharges:  0.9985740691192894

# %%
lt100_discharges = clean_limited_h_r_df[clean_limited_h_r_df['Number of Discharges'] < 100]['Excess Readmission Ratio']
gt1000_discharges = clean_limited_h_r_df[clean_limited_h_r_df['Number of Discharges'] > 1000]['Excess Readmission Ratio']
print('Mean ERR less than 100 is: ', lt100_discharges.mean(), ' and % > 1 is: ', lt100_discharges[lt100_discharges>1].size * 100/lt100_discharges.size, '%')
print('Mean ERR greater than 100 is: ', gt1000_discharges.mean(), ' and % > 1 is: ', gt1000_discharges[gt1000_discharges>1].size * 100/gt1000_discharges.size, '%')
# Out:
# Mean ERR less than 100 is:  1.0226183501683506  and % > 1 is:  63.215488215488215 %
# Mean ERR greater than 100 is:  0.9790730434782613  and % > 1 is:  44.56521739130435 %

# %%
lt_discharges = clean_limited_h_r_df[clean_limited_h_r_df['Number of Discharges'] < 100]
print(lt_discharges.groupby(['Measure Name'])['Excess Readmission Ratio'].mean())
gt_discharges = clean_limited_h_r_df[(clean_limited_h_r_df['Number of Discharges'] > 1000) & (clean_limited_h_r_df['Number of Discharges'] > 1000)]
print(gt_discharges.groupby(['Measure Name'])['Excess Readmission Ratio'].count())
# Out:
# Measure Name
# READM-30-AMI-HRRP         1.030549
# READM-30-COPD-HRRP        1.005972
# READM-30-HF-HRRP          1.017506
# READM-30-HIP-KNEE-HRRP    1.335367
# READM-30-PN-HRRP          1.019898
# Name: Excess Readmission Ratio, dtype: float64
# Measure Name
# READM-30-AMI-HRRP          31
# READM-30-COPD-HRRP         55
# READM-30-HF-HRRP          177
# READM-30-HIP-KNEE-HRRP    141
# READM-30-PN-HRRP           56
# Name: Excess Readmission Ratio, dtype: int64

# %%
def pearson_r(x, y):
    """Compute Pearson correlation coefficient between two arrays."""
    # Compute correlation matrix: corr_mat
    corr_mat = np.corrcoef(x,y)

    # Return entry [0,1]
    return corr_mat[0,1]

dis = clean_limited_h_r_df['Number of Discharges']
reds = clean_limited_h_r_df['Number of Readmissions']

_ = plt.plot(dis,reds,marker='.',linestyle='none')
_ = plt.margins(0.02)                     
plt.xlabel('Number of discharges')
plt.ylabel('Number of Readmissions')
plt.show()

obs_p = pearson_r(dis,reds)

print(obs_p)
# Out:
# 0.802485320133

# %%
ami = clean_limited_h_r_df[clean_limited_h_r_df['Measure Name'] == 'READM-30-AMI-HRRP']
copd = clean_limited_h_r_df[clean_limited_h_r_df['Measure Name'] == 'READM-30-COPD-HRRP']
hf = clean_limited_h_r_df[clean_limited_h_r_df['Measure Name'] == 'READM-30-HF-HRRP']
hk = clean_limited_h_r_df[clean_limited_h_r_df['Measure Name'] == 'READM-30-HIP-KNEE-HRRP']
pn = clean_limited_h_r_df[clean_limited_h_r_df['Measure Name'] == 'READM-30-PN-HRRP']
n_hk = clean_limited_h_r_df[clean_limited_h_r_df['Measure Name'] != 'READM-30-HIP-KNEE-HRRP']

# %%
dis_ami = ami['Number of Discharges']
reds_ami = ami['Number of Readmissions']

_ = plt.plot(dis_ami,reds_ami,marker='.',linestyle='none')
_ = plt.margins(0.02)                     
plt.xlabel('Number of discharges')
plt.ylabel('Number of Readmissions')
plt.show()

print(pearson_r(dis_ami,reds_ami))
# Out:
# 0.951448947102

# %%
dis_copd = copd['Number of Discharges']
reds_copd = copd['Number of Readmissions']

_ = plt.plot(dis_copd,reds_copd,marker='.',linestyle='none')
_ = plt.margins(0.02)                     
plt.xlabel('Number of discharges')
plt.ylabel('Number of Readmissions')
plt.show()

print(pearson_r(dis_copd,reds_copd))
# Out:
# 0.976637435364

# %%
dis_hf = hf['Number of Discharges']
reds_hf = hf['Number of Readmissions']

_ = plt.plot(dis_hf,reds_hf,marker='.',linestyle='none')
_ = plt.margins(0.02)                     
plt.xlabel('Number of discharges')
plt.ylabel('Number of Readmissions')
plt.show()

print(pearson_r(dis_hf,reds_hf))
# Out:
# 0.977713763881

# %%
dis_hk = hk['Number of Discharges']
reds_hk = hk['Number of Readmissions']

_ = plt.plot(dis_hk,reds_hk,marker='.',linestyle='none')
_ = plt.margins(0.02)                     
plt.xlabel('Number of discharges')
plt.ylabel('Number of Readmissions')
plt.show()

print(pearson_r(dis_hk,reds_hk))
# Out:
# 0.885504611639

# %%
dis_pn = pn['Number of Discharges']
reds_pn = pn['Number of Readmissions']

_ = plt.plot(dis_pn,reds_pn,marker='.',linestyle='none')
_ = plt.margins(0.02)                     
plt.xlabel('Number of discharges')
plt.ylabel('Number of Readmissions')
plt.show()

print(pearson_r(dis_pn,reds_pn))
# Out:
# 0.963445823904

# %%
dis = n_hk['Number of Discharges']
reds = n_hk['Excess Readmission Ratio']

_ = plt.plot(dis,reds,marker='.',linestyle='none')
_ = plt.margins(0.02)                     
plt.xlabel('Number of discharges')
plt.ylabel('Excess Readmission Ratio')
plt.show()

print(pearson_r(dis,reds))
# Out:
# -0.00873655411367

# %% [markdown]
# #### Test null hypothesis that the Number of Discharges are not correlated to Number of Readmissions.
# ##### As you can see that the probability of that is 0. Less than the alpha of 0.1. Meaning that the two are definitely correlated.

# %%
dis = clean_limited_h_r_df['Number of Discharges']
reds = clean_limited_h_r_df['Number of Readmissions']

size = 10000
perm_res = np.empty(size)

for i in range(size):
    reds_p = np.random.permutation(reds)
    perm_res[i] = pearson_r(dis,reds_p)


p_val = np.sum(perm_res >= obs_p)/len(perm_res)

print('The p-value that the pearson coefficient is by chance is : ',p_val)
# Out:
# The p-value that the pearson coefficient is by chance is :  0.0

# %% [markdown]
# ### Hypothesis #2
# #### Now we test another hypothesis. We take a subset of data for Measure name that are specific to 'READM-30-HIP-KNEE-HRRP'
# ##### As you can see, the correlation of number of discharges to Excess Readmission Ratio is negative, and by far is the major factor affecting the original comparison. Also, the probability of that happening by chance is 0.

# %%
dis_hk = hk['Number of Discharges']
reds_hk = hk['Excess Readmission Ratio']

_ = plt.figure(figsize=(10,5))
_ = plt.plot(dis_hk,reds_hk,marker='.',linestyle='none')
_ = plt.margins(0.02)                     
plt.xlabel('Number of discharges')
plt.ylabel('Excess Readmission Ratio')

plt.show()

obs_p_hk = pearson_r(dis_hk,reds_hk)

print('Observed pearson coefficient of READM-30-HIP-KNEE-HRRP measures is: ', obs_p_hk)

# We will check if this is by chance. 

size = 10000
perm_hk = np.empty(size)

for i in range(size):
    perm_reds_hk = np.random.permutation(reds_hk)
    perm_hk[i] = pearson_r(dis_hk,perm_reds_hk)
    
p_val_hk = np.sum(perm_hk <= obs_p_hk)/len(perm_hk)

print('The p-value of this happening by chance is : ', p_val_hk)
# Out:
# Observed pearson coefficient of READM-30-HIP-KNEE-HRRP measures is:  -0.360949691977
# The p-value of this happening by chance is :  0.0

# %%
hk_lt_500 = hk[hk['Number of Discharges'] <=500]
hk_gt_500 = hk[hk['Number of Discharges'] > 500]

# x, y = np.polyfit(hk_lt_500['Number of Discharges'], hk_lt_500['Excess Readmission Ratio'],1)

dis_hk = hk_lt_500['Number of Discharges']
reds_hk = hk_lt_500['Excess Readmission Ratio']

_ = plt.figure(figsize=(10,5))
_ = plt.plot(dis_hk,reds_hk,marker='.',linestyle='none')
_ = plt.margins(0.02)                     
plt.xlabel('Number of discharges')
plt.ylabel('Excess Readmission Ratio')

plt.show()
